# %%
import argparse
import glob
import os
import shutil
import sys
from PIL import Image
import numpy as np
import cv2

# %%
from Object_Detection_Metrics.metrics import calculate_metrics, draw_bounding_boxes_truth_pred

# %%
dict_name = {0 : 'bouchon_casse', 1 : 'trou', 2 : 'deforme', 3 : 'delamine'}

# %%
calculate_metrics(dict_name, gtFolder='/home/psycle/PsycleResearch/Babynov/groundtruths', 
                  detFolder='/home/psycle/PsycleResearch/Babynov/detections', iouThreshold=0.3, showPlot=True, gtCoordinates='rel', detCoordinates='rel',
                      imgSize='640,640', savePath='/home/psycle/PsycleResearch/Babynov/results')
# Out:
# Save folder /home/psycle/PsycleResearch/Babynov/results
# Save folder /home/psycle/PsycleResearch/Babynov/results
# Save folder /home/psycle/PsycleResearch/Babynov/results
# AP: 100.00% (0)
# AP: 60.00% (2)
# AP: 50.00% (3)
# mAP: 70.00%

# %%
draw_bounding_boxes_truth_pred(dict_name, '/home/psycle/PsycleResearch/Babynov/groundtruths',
                               '/home/psycle/PsycleResearch/Babynov/groundtruths', 
                               '/home/psycle/PsycleResearch/Babynov/results/images', 
                               '/home/psycle/PsycleResearch/Babynov/detections')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-963c55834a3e> in <module>
#       2                                '/home/psycle/PsycleResearch/Babynov/groundtruths',
#       3                                '/home/psycle/PsycleResearch/Babynov/results/images',
# ----> 4                                '/home/psycle/PsycleResearch/Babynov/detections')
#
# ~/PsycleResearch/env_object_detect/lib/python3.6/site-packages/Object_Detection_Metrics/metrics.py in draw_bounding_boxes_truth_pred(dict_name, gt_annotations, img_folder, results, prediction_annotations)
#     234     results : folder where results are to be saved
#     235     """
# --> 236     draw_boxes(dict_name, gt_annotations, img_folder, results, isGT=True)
#     237     draw_boxes(dict_name, prediction_annotations, img_folder, results, isGT=False)
#     238     add_legend(results)
#
# ...

# %%
################################################################################
